# %% [markdown]
# <a href="https://colab.research.google.com/github/daini10421/Covid19-MachineLearningProject-/blob/main/Machine_Learning_Project_Covid_19_Vaccines_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Covid-19 Vaccines Analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("/content/country_vaccinations.csv")
data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#data description
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.963000e+03       2.859000e+03             2.330000e+03
# mean         5.582017e+06       4.150892e+06             1.950739e+06
# std          1.490608e+07       1.100666e+07             4.780803e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.079370e+05       7.540600e+04             6.058575e+04
# 50%          8.868540e+05       5.936320e+05             4.673385e+05
# 75%          4.159876e+06       3.323364e+06             1.420076e+06
# max          1.345396e+08       1.003711e+08             3.803536e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.398000e+03        5.520000e+03
# mean             1.014896e+05        5.116634e+04
# std              2.396335e+05        1.594551e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.786750e+03        5.410000e+02
# ...

# %%
data.country.value_counts()
# Out:
# Canada                             225
# Bahrain                            216
# Austria                            212
# Belgium                            210
# Argentina                          210
# Bulgaria                           209
# Cayman Islands                     204
# Belarus                            203
# Albania                            197
# Bermuda                            195
# Brazil                             192
# Azerbaijan                         191
# Bangladesh                         182
# Andorra                            176
# Anguilla                           170
# Cambodia                           168
# Bolivia                            166
# Australia                          162
# Barbados                           160
# Antigua and Barbuda                157
# Afghanistan                        153
# Belize                             146
# Bosnia and Herzegovina             145
# Angola                             141
# ...

# %%
data.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                         993
# Oxford/AstraZeneca, Pfizer/BioNTech                                        868
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech              631
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V          382
# Oxford/AstraZeneca, Sinopharm/Beijing                                      368
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                               346
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                    342
# Oxford/AstraZeneca, Sinovac, Sputnik V                                     308
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                           210
# Sinopharm/Beijing, Sputnik V                                               203
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac              192
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing            182
# ...

# %%
#refined  our required data
df=data[["vaccines","country"]]
df.head()
# Out:
#                                             vaccines      country
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  Afghanistan

# %%
dict={}
for i in df.vaccines.unique():
    dict[i]=[df["country"][j] for j in df[df["vaccines"]==i].index]

#print(dict)
vaccines={}
for key, value in dict.items():
    vaccines[key]=set(value)

print(vaccines)
# Out:
# {'Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing': {'Afghanistan'}, 'Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V': {'Albania', 'Bosnia and Herzegovina'}, 'Sputnik V': {'Algeria'}, 'Oxford/AstraZeneca, Pfizer/BioNTech': {'Bermuda', 'Andorra', 'Cape Verde', 'Australia', 'Cayman Islands'}, 'Oxford/AstraZeneca': {'British Virgin Islands', 'Bahamas', 'Anguilla', 'Burkina Faso', 'Angola', 'Botswana', 'Antigua and Barbuda', 'Barbados'}, 'Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V': {'Argentina'}, 'Oxford/AstraZeneca, Sinovac, Sputnik V': {'Azerbaijan', 'Armenia'}, 'Pfizer/BioNTech': {'Aruba'}, 'Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech': {'Austria', 'Bulgaria', 'Belgium'}, 'Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V': {'Bolivia', 'Bahrain'}, 'Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing': {'Bangladesh'}, 'Sinopharm/Beijing, Sputnik V': {'Belarus'}, 'Oxford/AstraZeneca, Sinopharm/Beijing'
# ...

# %%
import plotly.express as px
import plotly.offline as py

v_map=px.choropleth(data, locations='iso_code', color='vaccines')
v_map.update_layout(height=500)

v_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
